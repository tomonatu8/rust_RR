# %% [markdown]
# # 数値実験結果の表示

# %% [markdown]
# ## (1) ラウンド数は固定で，エージェントの数を増加させる
# ### $\log_2 n$ との関係を調べる

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
filename_csv = '../rust_rr/incident_list.csv'
df = pd.read_csv(filename_csv,header=None)
print(df)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df.loc[:,0], df.loc[:,1], label='Results')
ax.plot(df.loc[:,0], df.loc[:,2], label='log_2 N')
ax.plot(df.loc[:,0],2*df.loc[:,2], label='2*log_2 N')
ax.legend()
ax.set_xlabel("N")
ax.grid(which = "major", axis = "x",  alpha = 0.8,
        linestyle = "--", linewidth = 1)

ax.grid(which = "major", axis = "y", alpha = 0.8,
        linestyle = "--", linewidth = 1)
# Out:
#           0     1          2
# 0       8.0   4.0   3.000000
# 1      16.0   7.0   4.000000
# 2      32.0   9.0   5.000000
# 3      64.0  11.0   6.000000
# 4     128.0  13.0   7.000000
# 5     400.0  16.0   8.643856
# 6     600.0  17.0   9.228819
# 7    1000.0  18.0   9.965784
# 8    2000.0  20.0  10.965784
# 9    3000.0  21.0  11.550747
# 10   5000.0  22.0  12.287712
# 11   7000.0  23.0  12.773139
# 12   8000.0  23.0  12.965784
# 13  10000.0  23.0  13.287712
# 14  20000.0  25.0  14.287712

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
filename_csv = '../rust_rr/incident_list_2.csv'
df = pd.read_csv(filename_csv,header=None)
print(df)
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df.loc[:,0], df.loc[:,1], label='Results')
ax.plot(df.loc[:,0], df.loc[:,2], label='log_2 N')
ax.plot(df.loc[:,0],2*df.loc[:,2], label='2*log_2 N')
ax.legend()
ax.set_xlabel("N")
ax.grid(which = "major", axis = "x",  alpha = 0.8,
        linestyle = "--", linewidth = 1)

ax.grid(which = "major", axis = "y", alpha = 0.8,
        linestyle = "--", linewidth = 1)
# Out:
#           0     1          2
# 0       8.0   4.0   3.000000
# 1      16.0   7.0   4.000000
# 2      32.0  11.0   5.000000
# 3      64.0  18.0   6.000000
# 4     128.0  29.0   7.000000
# 5     400.0  37.0   8.643856
# 6     600.0  40.0   9.228819
# 7    1000.0  43.0   9.965784
# 8    2000.0  47.0  10.965784
# 9    3000.0  49.0  11.550747
# 10   5000.0  52.0  12.287712
# 11   7000.0  54.0  12.773139
# 12   8000.0  54.0  12.965784
# 13  10000.0  55.0  13.287712
# 14  20000.0  59.0  14.287712

# %% [markdown]
# ## (2) エージェントド数は固定で，ラウンドの数 (財の数) を増加させる

# %% [markdown]
# ### $n = 8$

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

n = "8"
filename_csv = '../rust_rr/' + n + '_incident_list_.csv'
df = pd.read_csv(filename_csv,header=None)
print(df)
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df.loc[:,0], df.loc[:,1], label='Results')
ax.legend()
ax.set_title("n = " + n)
ax.set_xlabel("The number of rounds")
ax.grid(which = "major", axis = "x",  alpha = 0.8,
        linestyle = "--", linewidth = 1)

ax.grid(which = "major", axis = "y", alpha = 0.8,
        linestyle = "--", linewidth = 1)
# Out:
#         0    1
# 0     3.0  3.0
# 1    10.0  4.0
# 2    20.0  4.0
# 3    30.0  4.0
# 4    40.0  4.0
# 5    50.0  4.0
# 6    60.0  4.0
# 7    70.0  4.0
# 8    80.0  4.0
# 9    90.0  4.0
# 10  100.0  4.0
# 11  150.0  4.0
# 12  200.0  4.0
# 13  300.0  4.0
# 14  500.0  4.0

# %% [markdown]
# ### $n = 10$

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

n = "10"
filename_csv = '../rust_rr/' + n + '_incident_list_.csv'
df = pd.read_csv(filename_csv,header=None)
print(df)
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df.loc[:,0], df.loc[:,1], label='Results')
ax.legend()
ax.set_title("n = " + n)
ax.set_xlabel("The number of rounds")
ax.grid(which = "major", axis = "x",  alpha = 0.8,
        linestyle = "--", linewidth = 1)

ax.grid(which = "major", axis = "y", alpha = 0.8,
        linestyle = "--", linewidth = 1)
# Out:
#         0    1
# 0     3.0  4.0
# 1    10.0  5.0
# 2    20.0  5.0
# 3    30.0  5.0
# 4    40.0  5.0
# 5    50.0  5.0
# 6    60.0  5.0
# 7    70.0  5.0
# 8    80.0  5.0
# 9    90.0  5.0
# 10  100.0  5.0
# 11  150.0  5.0
# 12  200.0  5.0
# 13  300.0  5.0
# 14  500.0  5.0

# %% [markdown]
# ### $n = 100$

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

n = "100"
filename_csv = '../rust_rr/' + n + '_incident_list_.csv'
df = pd.read_csv(filename_csv,header=None)
print(df)
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df.loc[:,0], df.loc[:,1], label='Results')
ax.legend()
ax.set_title("n = " + n)
ax.set_xlabel("The number of rounds")
ax.grid(which = "major", axis = "x",  alpha = 0.8,
        linestyle = "--", linewidth = 1)

ax.grid(which = "major", axis = "y", alpha = 0.8,
        linestyle = "--", linewidth = 1)
# Out:
#         0     1
# 0     3.0   7.0
# 1    10.0  12.0
# 2    20.0  15.0
# 3    30.0  18.0
# 4    40.0  20.0
# 5    50.0  21.0
# 6    60.0  23.0
# 7    70.0  24.0
# 8    80.0  25.0
# 9    90.0  25.0
# 10  100.0  25.0
# 11  150.0  25.0
# 12  200.0  25.0
# 13  300.0  25.0
# 14  500.0  25.0

# %% [markdown]
# ### $n = 1000$

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

n = "1000"
filename_csv = '../rust_rr/' + n + '_incident_list_.csv'
df = pd.read_csv(filename_csv,header=None)
print(df)
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df.loc[:,0], df.loc[:,1], label='Results')
ax.legend()
ax.set_title("n = "+n)
ax.set_xlabel("The number of rounds")
ax.grid(which = "major", axis = "x",  alpha = 0.8,
        linestyle = "--", linewidth = 1)

ax.grid(which = "major", axis = "y", alpha = 0.8,
        linestyle = "--", linewidth = 1)
# Out:
#          0      1
# 0      3.0   11.0
# 1     10.0   17.0
# 2     20.0   23.0
# 3     30.0   26.0
# 4     40.0   30.0
# 5     50.0   32.0
# 6     60.0   35.0
# 7     70.0   37.0
# 8     80.0   39.0
# 9     90.0   41.0
# 10   100.0   43.0
# 11   150.0   51.0
# 12  1000.0  104.0
# 13  1500.0  104.0
# 14  2000.0  104.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


filename_csv = '../rust_rr/all_incident_list.csv'
df = pd.read_csv(filename_csv,header=None)
print(df)
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df.loc[:,0], df.loc[:,1], label='Results', linestyle='None', marker="*")
ax.legend()
ax.set_xlabel("The number of agents")
ax.grid(which = "major", axis = "x",  alpha = 0.8,
        linestyle = "--", linewidth = 1)

ax.grid(which = "major", axis = "y", alpha = 0.8,
        linestyle = "--", linewidth = 1)
# Out:
#          0     1
# 0      4.0   2.0
# 1      5.0   2.0
# 2      6.0   3.0
# 3      7.0   3.0
# 4      8.0   4.0
# ..     ...   ...
# 291  295.0  49.0
# 292  296.0  49.0
# 293  297.0  49.0
# 294  298.0  50.0
# 295  299.0  50.0
#
# [296 rows x 2 columns]
